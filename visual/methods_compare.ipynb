# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path_acc_unet = 'model/trained/unet_metrics.csv'
path_acc_deeplabv3plus = 'model/trained/deeplabv3plus_metrics.csv'
path_acc_deeplabv3plus_mb2 = 'model/trained/deeplabv3plus_mobilev2_metrics.csv'
path_acc_watnet = 'model/trained/watnet_metrics.csv'
acc_unet_df = pd.read_csv(path_acc_unet)
acc_deeplabv3plus_df = pd.read_csv(path_acc_deeplabv3plus)
acc_deeplabv3plus_mb2_df = pd.read_csv(path_acc_deeplabv3plus_mb2)
acc_watnet_df = pd.read_csv(path_acc_watnet)
acc_unet_df.head()
# Out:
#    tra_loss  tra_miou    tra_oa  val_loss  val_miou    val_oa
# 0  0.547881  0.582764  0.699898  0.814130  0.113929  0.287841
# 1  0.592207  0.342561  0.419890  0.546119  0.386072  0.386072
# 2  0.547066  0.370705  0.370705  0.466229  0.386072  0.386072
# 3  0.402629  0.393076  0.393076  0.351611  0.386072  0.386072
# 4  0.300856  0.533747  0.669290  0.249586  0.659823  0.810526

# %%
accs_df = [acc_unet_df, acc_deeplabv3plus_df, acc_deeplabv3plus_mb2_df, acc_watnet_df]
colors = ['blue', 'orange', 'green', 'red']
labels = ['val_miou_unet', 
          'val_miou_deeplabv3plus', 
          'val_miou_deeplabv3plus_mb2',
          'val_miou_watnet']

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, acc_df in enumerate(accs_df):
    sns.lineplot(data=acc_df, 
                x=acc_df.index, 
                y='val_miou', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
ax.set_ylim(0.5, 1)
# Out:
# (0.5, 1.0)

# %%
fig, ax = plt.subplots(figsize=(6, 4))
for i, acc_df in enumerate(accs_df):
    sns.lineplot(data=acc_df, 
                x=acc_df.index, 
                y='tra_loss', 
                label=labels[i],
                color=colors[i],
                ax=ax)
ax.set_xlabel('Epochs')
# ax.set_ylim(0.6, 1)
# Out:
# Text(0.5, 0, 'Epochs')
