# %% [markdown]
# ### **Check the remote sensing scenes of the dataset.**

# %%
import numpy as np
from glob import glob
import rasterio as rio 
import matplotlib.pyplot as plt
from utils.imgShow import imgShow, imsShow
from notebooks import config

# %%
path_s2_scene1 = config.dir_scene + '/S2A_L2A_20190125_N0211_R034_6Bands_S1.tif'
path_s2_truth1 = config.dir_truth + '/S2A_L2A_20190125_N0211_R034_S1_Truth.tif'
s2_scene1_rio = rio.open(path_s2_scene1)
s2_truth1_rio = rio.open(path_s2_truth1)

# %%
plt.figure(figsize=(7,3))
img_list = [s2_scene1_rio.read().transpose(1,2,0), 
            s2_truth1_rio.read().transpose(1,2,0)]
img_name_list=['s2 scene', 's2 truth']
clip_list=[2,2]
color_bands_list=[[2,1,0],[0,0,0]]
imsShow(img_list, img_name_list, clip_list, color_bands_list)
